# %%
import transformer_lens
from transformer_lens import utils
import torch
import tqdm
from utils import *
# Load a model (eg GPT-2 Small)
model = transformer_lens.HookedTransformer.from_pretrained("gpt2-small")
# Out:
# Using pad_token, but it is not set yet.
# Loaded pretrained model gpt2-small into HookedTransformer

# %%
import torch
import blobfile as bf
import transformer_lens
import sparse_autoencoder


layer_index = 0  # in range(12)
autoencoder_input = ["mlp_post_act", "resid_delta_mlp"][1]
filename = f"az://openaipublic/sparse-autoencoder/gpt2-small/{autoencoder_input}/autoencoders/{layer_index}.pt"
with bf.BlobFile(filename, mode="rb") as f:
    state_dict = torch.load(f)
    autoencoder = sparse_autoencoder.Autoencoder.from_state_dict(state_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 11
#       9 filename = f"az://openaipublic/sparse-autoencoder/gpt2-small/{autoencoder_input}/autoencoders/{layer_index}.pt"
#      10 with bf.BlobFile(filename, mode="rb") as f:
# ---> 11     state_dict = torch.load(f)
#      12     autoencoder = sparse_autoencoder.Autoencoder.from_state_dict(state_dict)
#
# File ~/miniconda3/envs/interp/lib/python3.11/site-packages/torch/serialization.py:1014, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1012             except RuntimeError as e:
#    1013                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1014         return _load(opened_zipfile,
#    1015                      map_location,
#    1016                      pickle_module,
#    1017                      overall_storage=overall_storage,
# ...

# %%
import torch
import blobfile as bf
import sparse_autoencoder

layer_index = 0  # in range(12)
autoencoder_input = ["mlp_post_act", "resid_delta_mlp"][1]
remote_filename = f"az://openaipublic/sparse-autoencoder/gpt2-small/{autoencoder_input}/autoencoders/{layer_index}.pt"
local_filename = f"{layer_index}.pt"

# Open a connection to the remote file
with bf.BlobFile(remote_filename, mode="rb") as remote_file:
    # Open a local file to save the downloaded data
    with open(local_filename, mode="wb") as local_file:
        # Copy the data from the remote file to the local file
        local_file.write(remote_file.read())

# Now you can load the state_dict from the local file
state_dict = torch.load(local_filename)
autoencoder = sparse_autoencoder.Autoencoder.from_state_dict(state_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 15
#      11 with bf.BlobFile(remote_filename, mode="rb") as remote_file:
#      12     # Open a local file to save the downloaded data
#      13     with open(local_filename, mode="wb") as local_file:
#      14         # Copy the data from the remote file to the local file
# ---> 15         local_file.write(remote_file.read())
#      17 # Now you can load the state_dict from the local file
#      18 state_dict = torch.load(local_filename)
#
# File ~/miniconda3/envs/interp/lib/python3.11/site-packages/blobfile/_common.py:881, in BaseStreamingReadFile.readall(self)
#     879 assert bytes_remaining >= 0, "read more bytes than expected"
#     880 # if a user doesn't like this value, it is easy to use .read(size) directly
# --> 881 opt_piece = self.read(min(CHUNK_SIZE, bytes_remaining))
# ...
